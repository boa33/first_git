# %%
# !cd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
fig, ax = plt.subplots(nrows =2, ncols=2)
ax[1,1].plot([1, 2, 3, 4], [1, 4, 2, 3])# 윗줄과 같은 줄에 입력해야 출력된다.
ax[0,0].plot([1, 2, 3, 4], [3, 2, 1, 2])
fig.suptitle('Vertically stacked subplots')
fig.supxlabel('X Vertically stacked subplots')
#fig는 전체 ax는 일부적
# Out:
# Text(0.5, 0.01, 'X Vertically stacked subplots')

# %%
# ax[0] #첫번째 줄에 해당하는 것
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]) # ax대신 plt를 주어도 상관 없음

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
import pandas

# %%
a = pandas.DataFrame(np.random.rand(4, 5), columns = list('abcde'))

# %%
import numpy as np

# %%
np_array
# Out:
# array([[0.70392051, 0.94652856, 0.02851386, 0.18175471, 0.48394423],
#        [0.00569252, 0.51481632, 0.63837536, 0.98204237, 0.21050139],
#        [0.96146181, 0.75182608, 0.10183306, 0.65318447, 0.76144948],
#        [0.02691319, 0.45785681, 0.97932621, 0.36501498, 0.66920724]])

# %%
np_array = a.values

# %%
np_array.mean() #평균
# Out:
# 0.5212081581513102

# %%
np_array.std() #표준편차
# Out:
# 0.3289839302315925

# %%
np_array.var() #분산
# Out:
# 0.10823042635062534

# %%
b = np.matrix([[1, 2], [3, 4]])

# %%
b
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
b_asarray = np.asarray(b)

# %%
x=a

# %%
x = np.linspace(0, 2, 100) #0부터 2까지 100으로 쪼갬

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend(loc=0, fontsize='xx-large') #loc 네모박스 위치

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
#
